# %%
! pip install yfinance

# %%
import yfinance as yf

# %%
import statsmodels

# %%
ticker = yf.Ticker("TATAMOTORS.NS")

# %%
ticker.info
# Out:
# {'address1': 'Ahura Centre',
#  'address2': '4th Floor 82 Mahakali Caves Road, MIDC Andheri (East)',
#  'city': 'Mumbai',
#  'zip': '400 093',
#  'country': 'India',
#  'phone': '91 22 6240 7101',
#  'website': 'https://www.tatamotors.com',
#  'industry': 'Auto Manufacturers',
#  'industryKey': 'auto-manufacturers',
#  'industryDisp': 'Auto Manufacturers',
#  'sector': 'Consumer Cyclical',
#  'sectorKey': 'consumer-cyclical',
#  'sectorDisp': 'Consumer Cyclical',
# ...

# %%
ticker.history_metadata
# Out:
# {'currency': 'INR',
#  'symbol': 'TATAMOTORS.NS',
#  'exchangeName': 'NSI',
#  'fullExchangeName': 'NSE',
#  'instrumentType': 'EQUITY',
#  'firstTradeDate': 662787900,
#  'regularMarketTime': 1737453600,
#  'hasPrePostMarketData': False,
#  'gmtoffset': 19800,
#  'timezone': 'IST',
#  'exchangeTimezoneName': 'Asia/Kolkata',
#  'regularMarketPrice': 760.75,
#  'fiftyTwoWeekHigh': 1179.0,
#  'fiftyTwoWeekLow': 717.7,
#  'regularMarketDayHigh': 786.65,
#  'regularMarketDayLow': 758.4,
#  'regularMarketVolume': 11654827,
#  'longName': 'Tata Motors Limited',
#  'shortName': 'TATA MOTORS LIMITED',
#  'chartPreviousClose': 763.6,
#  'previousClose': 774.35,
#  'scale': 3,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'timezone': 'IST',
#    'end': 1737431100,
#    'start': 1737431100,
#    'gmtoffset': 19800},
#   'regular': {'timezone': 'IST',
#    'end': 1737453600,
#    'start': 1737431100,
#    'gmtoffset': 19800},
#   'post': {'timezone': 'IST',
#    'end': 1737453600,
# ...

# %%
ticker.get_financials()
# Out:
#                                          2024-03-31       2023-03-31  \
# TaxEffectOfUnusualItems               -6554370000.0     1195840000.0
# TaxRateForCalcs                                 0.3              0.2
# NormalizedEBITDA                     673957900000.0   378818500000.0
# TotalUnusualItems                    -21847900000.0     5979200000.0
# TotalUnusualItemsExcludingGoodwill   -21847900000.0     5979200000.0
# ...                                             ...              ...
# SalariesAndWages                                NaN              NaN
# GrossProfit                         1490464900000.0  1047343500000.0
# CostOfRevenue                       2859376300000.0  2381402400000.0
# TotalRevenue                        4349841200000.0  3428745900000.0
# OperatingRevenue                    4349841200000.0  3428745900000.0
#
#                                          2022-03-31       2021-03-31  \
# ...

# %%
ticker.income_stmt
# Out:
#                                              2024-03-31       2023-03-31  \
# Tax Effect Of Unusual Items               -6554370000.0     1195840000.0
# Tax Rate For Calcs                                  0.3              0.2
# Normalized EBITDA                        673957900000.0   378818500000.0
# Total Unusual Items                      -21847900000.0     5979200000.0
# Total Unusual Items Excluding Goodwill   -21847900000.0     5979200000.0
# ...                                                 ...              ...
# Salaries And Wages                                  NaN              NaN
# Gross Profit                            1490464900000.0  1047343500000.0
# Cost Of Revenue                         2859376300000.0  2381402400000.0
# Total Revenue                           4349841200000.0  3428745900000.0
# Operating Revenue                       4349841200000.0  3428745900000.0
#
#                                              2022-03-31       2021-03-31  \
# ...

# %%
df = yf.download("TATAMOTORS.NS")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.to_csv('tata.csv')

# %%
df= yf.download("TATAMOTORS.NS", start="2020-05-13", end="2024-05-13", rounding=True)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df['Close']
# Out:
# Ticker      TATAMOTORS.NS
# Date
# 2020-05-13          86.66
# 2020-05-14          83.28
# 2020-05-15          83.83
# 2020-05-18          80.15
# 2020-05-19          81.29
# ...                   ...
# 2024-05-06        1013.07
# 2024-05-07         985.51
# 2024-05-08        1008.99
# 2024-05-09        1027.13
# 2024-05-10        1043.43
#
# [991 rows x 1 columns]

# %%
df['Close'].diff().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df['Close'].diff()
# Out:
# Ticker      TATAMOTORS.NS
# Date
# 2020-05-13            NaN
# 2020-05-14          -3.38
# 2020-05-15           0.55
# 2020-05-18          -3.68
# 2020-05-19           1.14
# ...                   ...
# 2024-05-06           2.79
# 2024-05-07         -27.56
# 2024-05-08          23.48
# 2024-05-09          18.14
# 2024-05-10          16.30
#
# [991 rows x 1 columns]

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adfuller(df['Close'].diff().dropna() )
# Out:
# (-15.185822162008147,
#  6.106840602066645e-28,
#  3,
#  986,
#  {'1%': -3.4369994990319355,
#   '5%': -2.8644757356011743,
#   '10%': -2.5683331327427803},
#  7162.732898677845)

# %%
df['Close']
# Out:
# Ticker      TATAMOTORS.NS
# Date
# 2020-05-13          86.66
# 2020-05-14          83.28
# 2020-05-15          83.83
# 2020-05-18          80.15
# 2020-05-19          81.29
# ...                   ...
# 2024-05-06        1013.07
# 2024-05-07         985.51
# 2024-05-08        1008.99
# 2024-05-09        1027.13
# 2024-05-10        1043.43
#
# [991 rows x 1 columns]

# %%
! pip install pmdarima

# %%
import pmdarima as pm

# %%
arima_model=pm.auto_arima(
    y=df['Close'],
    start_p=2, start_q=1,
    max_p=5, max_q=5, max_d=1, trace = True 
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=7315.868, Time=0.73 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=7321.002, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=7323.001, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=7323.001, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=7328.696, Time=0.03 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=7318.023, Time=0.52 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=7322.705, Time=0.15 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=7315.614, Time=0.41 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=7317.769, Time=0.18 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=7317.499, Time=0.83 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=7317.558, Time=0.98 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=7315.421, Time=0.68 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=7315.341, Time=0.34 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=7322.926, Time=0.20 sec
# ...

# %%
arima_model.predict(5)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/anaconda3/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# 991    1042.835389
# 992    1045.905804
# 993    1045.215471
# 994    1047.485511
# 995    1047.425214
# dtype: float64

# %% [markdown]
# Importing data from Yfinance
